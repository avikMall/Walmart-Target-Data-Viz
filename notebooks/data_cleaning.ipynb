# %%
import pandas as pd

target = pd.read_csv('target_final.csv')
walmart = pd.read_csv('walmart_final.csv')
census = pd.read_csv('county.csv')

# %%
walmart.shape
# Out:
# (4654, 35)

# %%
for index, value in enumerate(census['County'].values):
    if value[-6:] == 'County':
        value = value[:-7]
        census['County'].values[index] = value
census.head()
# Out:
#    CountyId    State   County  TotalPop    Men   Women  Hispanic  White  \
# 0      1001  Alabama  Autauga     55036  26899   28137       2.7   75.4
# 1      1003  Alabama  Baldwin    203360  99527  103833       4.4   83.1
# 2      1005  Alabama  Barbour     26201  13976   12225       4.2   45.7
# 3      1007  Alabama     Bibb     22580  12251   10329       2.4   74.6
# 4      1009  Alabama   Blount     57667  28490   29177       9.0   87.4
#
#    Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0   18.9     0.3  ...   0.6          1.3         2.5         25.8     24112
# 1    9.5     0.8  ...   0.8          1.1         5.6         27.0     89527
# 2   47.8     0.2  ...   2.2          1.7         1.3         23.4      8878
# 3   22.0     0.4  ...   0.3          1.7         1.5         30.0      8171
# 4    1.5     0.3  ...   0.4          0.4         2.1         35.0     21380
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
census['County'] = census['County'].str.strip().str.lower()
target['Address.County'] = target['Address.County'].str.strip().str.lower()
census.shape
# Out:
# (3220, 37)

# %%
census_deduped = census.drop_duplicates(subset=['County'], keep='first')
census_deduped.shape
# Out:
# (1955, 37)

# %%
merged_data = pd.merge(target, census_deduped, left_on=['Address.County'], right_on=['County'], how='left')
merged_data.shape
# Out:
# (1771, 93)

# %%
merged_data.to_csv('target_final.csv', index=False)

# %%
merged_data_2 = pd.merge(walmart, census_deduped, left_on=['COUNTYNAME'], right_on=['County'], how='left')
merged_data_2.shape
# Out:
# (4654, 72)

# %%
merged_data_2.head()
# Out:
#    Unnamed: 0                       name  \
# 0           0         Conway Supercenter
# 1           1       Sikeston Supercenter
# 2           2      Tahlequah Supercenter
# 3           3  Mountain Home Supercenter
# 4           4      Claremore Supercenter
#
#                                                  url          street_address  \
# 0  https://www.walmart.com/store/5/conway-ar/details       1155 Hwy 65 North
# 1  https://www.walmart.com/store/9/sikeston-mo/de...          1303 S Main St
# 2  https://www.walmart.com/store/10/tahlequah-ok/...     2020 S Muskogee Ave
# 3  https://www.walmart.com/store/11/mountain-home...          65 Wal Mart Dr
# 4  https://www.walmart.com/store/12/claremore-ok/...  1500 S Lynn Riggs Blvd
#
#             city state  zip_code country phone_number_1  phone_number_2  ...  \
# 0         Conway    AR     72032      US   501-329-0023             NaN  ...
# 1       Sikeston    MO     63801      US   573-472-3020             NaN  ...
# ...

# %%
merged_data_2.to_csv('walmart_final.csv')
